# %% [markdown]
# # ANZ

# %% [markdown]
# This is an analysis of ANZ Data@ANZ Program, from TheForage website (theforage.com).

# %% [markdown]
# ## Exploratory Data Analysis

# %% [markdown]
# ### Import relevant libaries

# %%
import pandas as pd
import datetime as dt
import time
import matplotlib.pyplot as plt

# %% [markdown]
# ### Read and explore the dataset

# %%
df = pd.read_excel("Downloads\ANZ synthesised transaction dataset.xlsx")
df.head()
# Out:
#        status  card_present_flag bpay_biller_code         account currency  \
# 0  authorized                1.0              NaN  ACC-1598451071      AUD
# 1  authorized                0.0              NaN  ACC-1598451071      AUD
# 2  authorized                1.0              NaN  ACC-1222300524      AUD
# 3  authorized                1.0              NaN  ACC-1037050564      AUD
# 4  authorized                1.0              NaN  ACC-1598451071      AUD
#
#         long_lat txn_description                           merchant_id  \
# 0  153.41 -27.95             POS  81c48296-73be-44a7-befa-d053f48ce7cd
# 1  153.41 -27.95       SALES-POS  830a451c-316e-4a6a-bf25-e37caedca49e
# 2  151.23 -33.94             POS  835c231d-8cdf-4e96-859d-e9d571760cf0
# 3  153.10 -27.66       SALES-POS  48514682-c78a-4a88-b0da-2d6302e64673
# 4  153.41 -27.95       SALES-POS  b4e02c10-0852-4273-b8fd-7b3395e32eb0
#
#    merchant_code first_name  ...  age merchant_suburb merchant_state  \
# ...

# %%
df.columns
# Out:
# Index(['status', 'card_present_flag', 'bpay_biller_code', 'account',
#        'currency', 'long_lat', 'txn_description', 'merchant_id',
#        'merchant_code', 'first_name', 'balance', 'date', 'gender', 'age',
#        'merchant_suburb', 'merchant_state', 'extraction', 'amount',
#        'transaction_id', 'country', 'customer_id', 'merchant_long_lat',
#        'movement'],
#       dtype='object')

# %% [markdown]
# Set dataframe to show all columns.

# %%
pd.set_option('display.max_columns', None)

# %%
df.head()
# Out:
#        status  card_present_flag bpay_biller_code         account currency  \
# 0  authorized                1.0              NaN  ACC-1598451071      AUD
# 1  authorized                0.0              NaN  ACC-1598451071      AUD
# 2  authorized                1.0              NaN  ACC-1222300524      AUD
# 3  authorized                1.0              NaN  ACC-1037050564      AUD
# 4  authorized                1.0              NaN  ACC-1598451071      AUD
#
#         long_lat txn_description                           merchant_id  \
# 0  153.41 -27.95             POS  81c48296-73be-44a7-befa-d053f48ce7cd
# 1  153.41 -27.95       SALES-POS  830a451c-316e-4a6a-bf25-e37caedca49e
# 2  151.23 -33.94             POS  835c231d-8cdf-4e96-859d-e9d571760cf0
# 3  153.10 -27.66       SALES-POS  48514682-c78a-4a88-b0da-2d6302e64673
# 4  153.41 -27.95       SALES-POS  b4e02c10-0852-4273-b8fd-7b3395e32eb0
#
#    merchant_code first_name  balance       date gender  age merchant_suburb  \
# ...

# %%
df.shape
# Out:
# (12043, 23)

# %% [markdown]
# There are 12043 rows and 23 columns in this table.

# %% [markdown]
# Below are the number of unique values for each column.

# %%
df.nunique()
# Out:
# status                   2
# card_present_flag        2
# bpay_biller_code         3
# account                100
# currency                 1
# long_lat               100
# txn_description          6
# merchant_id           5725
# merchant_code            1
# first_name              80
# balance              12006
# date                    91
# gender                   2
# age                     33
# merchant_suburb       1609
# merchant_state           8
# extraction            9442
# amount                4457
# transaction_id       12043
# country                  1
# customer_id            100
# merchant_long_lat     2703
# movement                 2
# dtype: int64

# %% [markdown]
# All transactions are in AUD, Australian dollars. The transactions were done at 100 locations.

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 12043 entries, 0 to 12042
# Data columns (total 23 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   status             12043 non-null  object
#  1   card_present_flag  7717 non-null   float64
#  2   bpay_biller_code   885 non-null    object
#  3   account            12043 non-null  object
#  4   currency           12043 non-null  object
#  5   long_lat           12043 non-null  object
#  6   txn_description    12043 non-null  object
#  7   merchant_id        7717 non-null   object
#  8   merchant_code      883 non-null    float64
#  9   first_name         12043 non-null  object
#  10  balance            12043 non-null  float64
#  11  date               12043 non-null  datetime64[ns]
#  12  gender             12043 non-null  object
#  13  age                12043 non-null  int64
#  14  merchant_suburb    7717 non-null   object
# ...

# %% [markdown]
# There are several missing values, indicated by above columns with counts less than 12043.

# %% [markdown]
# There are 100 accounts for 12043 transactions. Some merchants had more than one transaction. There is duplicity in first_name; only 80 first names are in the 12043 transactions. There are 1609 different suburbs. This contradicts the long_lat information and clarification will be needed for this discrepancy. There are 4326 null values for merchant_state. That's 35% of the data. Extraction is date and time information. There were 12043 different transactions, as shown by the transaction_id. All of the data is from Australia and included 100 customers. Clarification is needed for merchant_long_lat.

# %%
df.tail()
# Out:
#            status  card_present_flag bpay_biller_code         account  \
# 12038  authorized                0.0              NaN  ACC-3021093232
# 12039  authorized                1.0              NaN  ACC-1608363396
# 12040  authorized                1.0              NaN  ACC-3827517394
# 12041  authorized                1.0              NaN  ACC-2920611728
# 12042  authorized                1.0              NaN  ACC-1443681913
#
#       currency       long_lat txn_description  \
# 12038      AUD  149.83 -29.47             POS
# 12039      AUD  151.22 -33.87       SALES-POS
# 12040      AUD  151.12 -33.89             POS
# 12041      AUD  144.96 -37.76       SALES-POS
# 12042      AUD  150.92 -33.77       SALES-POS
#
#                                 merchant_id  merchant_code first_name  \
# 12038  32aa73dc-b7c2-4161-b14d-6271b96ce792            NaN    Melissa
# 12039  296a0500-8552-48ac-ac81-ec37065b568e            NaN     Robert
# ...

# %%
df['status'].unique()
# Out:
# array(['authorized', 'posted'], dtype=object)

# %% [markdown]
# Status is either authorized or posted. card_present_flag is 0 and 1, probably either yes or no.

# %%
df['bpay_biller_code'].unique()
# Out:
# array([nan, 0, ' THE DISCOUNT CHEMIST GROUP',
#        ' LAND WATER & PLANNING East Melbourne'], dtype=object)

# %% [markdown]
# Only two values are labeled for bpay_biller_code. These are THE DISCOUNT CHEMIST GROUP and LAND WATER & PLANNING East Melbourne.

# %%
df['txn_description'].unique()
# Out:
# array(['POS', 'SALES-POS', 'PAYMENT', 'INTER BANK', 'PAY/SALARY',
#        'PHONE BANK'], dtype=object)

# %% [markdown]
# There are six taxation descriptions.

# %%
df['merchant_code'].unique()
# Out:
# array([nan,  0.])

# %% [markdown]
# merchant_code does not provide any usable information and can be dropped.

# %%
df1 = df.drop('merchant_code', axis=1)
df1.head()
# Out:
#        status  card_present_flag bpay_biller_code         account currency  \
# 0  authorized                1.0              NaN  ACC-1598451071      AUD
# 1  authorized                0.0              NaN  ACC-1598451071      AUD
# 2  authorized                1.0              NaN  ACC-1222300524      AUD
# 3  authorized                1.0              NaN  ACC-1037050564      AUD
# 4  authorized                1.0              NaN  ACC-1598451071      AUD
#
#         long_lat txn_description                           merchant_id  \
# 0  153.41 -27.95             POS  81c48296-73be-44a7-befa-d053f48ce7cd
# 1  153.41 -27.95       SALES-POS  830a451c-316e-4a6a-bf25-e37caedca49e
# 2  151.23 -33.94             POS  835c231d-8cdf-4e96-859d-e9d571760cf0
# 3  153.10 -27.66       SALES-POS  48514682-c78a-4a88-b0da-2d6302e64673
# 4  153.41 -27.95       SALES-POS  b4e02c10-0852-4273-b8fd-7b3395e32eb0
#
#   first_name  balance       date gender  age merchant_suburb merchant_state  \
# ...

# %%
df1['merchant_state'].unique()
# Out:
# array(['QLD', 'NSW', nan, 'VIC', 'WA', 'SA', 'NT', 'TAS', 'ACT'],
#       dtype=object)

# %%
df1['movement'].unique()
# Out:
# array(['debit', 'credit'], dtype=object)

# %% [markdown]
# All of the transactions were debit or credit purchases.

# %%
df1.describe()
# Out:
#        card_present_flag        balance           age        amount
# count        7717.000000   12043.000000  12043.000000  12043.000000
# mean            0.802644   14704.195553     30.582330    187.933588
# std             0.398029   31503.722652     10.046343    592.599934
# min             0.000000       0.240000     18.000000      0.100000
# 25%             1.000000    3158.585000     22.000000     16.000000
# 50%             1.000000    6432.010000     28.000000     29.000000
# 75%             1.000000   12465.945000     38.000000     53.655000
# max             1.000000  267128.520000     78.000000   8835.980000

# %%
df1['amount'].mode()
# Out:
# 0    33.0
# dtype: float64

# %%
df1['gender'].value_counts()
# Out:
# M    6285
# F    5758
# Name: gender, dtype: int64

# %% [markdown]
# Balance ranged from 0.24AUD to 267,129AUD. There is a 60 years age span with the average at 31 years old. 0.10AUD for a transaction amount is very small. This may be a fee. The highest amount was 8836AUD, with an average of 188AUD.

# %% [markdown]
# Clarification is needed on the meaning of card_present_flag, since this dataset includes credit and debit transactions.

# %% [markdown]
# Let's gather the average transactions per month.

# %%
lowest_amount = df1[df1['amount'] == df1['amount'].min()]
lowest_amount.shape
# Out:
# (5, 26)

# %%
lowest_amount
# Out:
#            status  card_present_flag bpay_biller_code         account  \
# 5395   authorized                0.0              NaN   ACC-211792489
# 6428   authorized                1.0              NaN  ACC-3541460373
# 6592   authorized                1.0              NaN  ACC-2265520058
# 8188   authorized                1.0              NaN  ACC-1598451071
# 11523  authorized                0.0              NaN  ACC-3771436525
#
#       currency       long_lat txn_description  \
# 5395       AUD  138.63 -34.93       SALES-POS
# 6428       AUD  145.00 -37.83             POS
# 6592       AUD  151.27 -33.85             POS
# 8188       AUD  153.41 -27.95       SALES-POS
# 11523      AUD  145.04 -37.92       SALES-POS
#
#                                 merchant_id  first_name  balance       date  \
# 5395   3b6372a5-9b14-4d98-bb58-92c215bca597  Jacqueline  6090.60 2018-09-12
# 6428   a6a341db-200c-4833-a93d-893d18b019ea     Jeffrey  3281.56 2018-09-19
# ...

# %% [markdown]
# There are 26 cases in which the lowest amount is 0.10 AUD.

# %%
df1['month'] = df1.date.dt.month
df1.head(3)
# Out:
#        status  card_present_flag bpay_biller_code         account currency  \
# 0  authorized                1.0              NaN  ACC-1598451071      AUD
# 1  authorized                0.0              NaN  ACC-1598451071      AUD
# 2  authorized                1.0              NaN  ACC-1222300524      AUD
#
#         long_lat txn_description                           merchant_id  \
# 0  153.41 -27.95             POS  81c48296-73be-44a7-befa-d053f48ce7cd
# 1  153.41 -27.95       SALES-POS  830a451c-316e-4a6a-bf25-e37caedca49e
# 2  151.23 -33.94             POS  835c231d-8cdf-4e96-859d-e9d571760cf0
#
#   first_name  balance       date gender  age merchant_suburb merchant_state  \
# 0      Diana    35.39 2018-08-01      F   26         Ashmore            QLD
# 1      Diana    21.20 2018-08-01      F   26          Sydney            NSW
# 2    Michael     5.71 2018-08-01      M   38          Sydney            NSW
#
# ...

# %%
df1.groupby('month').mean()
# Out:
#        card_present_flag       balance        age      amount
# month
# 8               0.805128  10794.148620  30.482881  185.121867
# 9               0.799308  14730.151136  30.533516  182.045903
# 10              0.803565  18450.991566  30.726205  196.427323

# %% [markdown]
# Three months are represented for this dataset. The monthly average balance ranged from 10794AUD to 18461AUD, and the transaction amount was typically 182AUD to 196AUD.

# %%
df1['day_of_week'] = df1.date.dt.day_name()
df1.head(3)
# Out:
#        status  card_present_flag bpay_biller_code         account currency  \
# 0  authorized                1.0              NaN  ACC-1598451071      AUD
# 1  authorized                0.0              NaN  ACC-1598451071      AUD
# 2  authorized                1.0              NaN  ACC-1222300524      AUD
#
#         long_lat txn_description                           merchant_id  \
# 0  153.41 -27.95             POS  81c48296-73be-44a7-befa-d053f48ce7cd
# 1  153.41 -27.95       SALES-POS  830a451c-316e-4a6a-bf25-e37caedca49e
# 2  151.23 -33.94             POS  835c231d-8cdf-4e96-859d-e9d571760cf0
#
#   first_name  balance       date gender  age merchant_suburb merchant_state  \
# 0      Diana    35.39 2018-08-01      F   26         Ashmore            QLD
# 1      Diana    21.20 2018-08-01      F   26          Sydney            NSW
# 2    Michael     5.71 2018-08-01      M   38          Sydney            NSW
#
# ...

# %%
df1.groupby('day_of_week').mean()
# Out:
#              card_present_flag       balance        age      amount     month
# day_of_week
# Friday                0.803341  13669.240164  30.880849  249.353517  8.926676
# Monday                0.792453  15414.475029  29.925000  373.221000  9.083088
# Saturday              0.792072  15367.523019  30.803979   54.419286  9.009362
# Sunday                0.792185  13638.446710  29.653548   53.015845  9.049032
# Thursday              0.816863  16879.305541  31.669628  184.010422  8.998890
# Tuesday               0.807372  14766.759361  30.989240  221.576456  9.031607
# Wednesday             0.812950  13583.187814  29.987397  195.215570  9.022298

# %% [markdown]
# The account balance and age are fairly consistent across all days. However, the transaction amount varies greatly. The lowest average transactions were done on Sundays at 53AUD, and the highest was on Mondays at 373AUD.

# %%
df1['extraction_time'] = pd.to_datetime(df1['extraction'], format='%Y-%m-%d %H:%M:%S').dt.time
df1.head(3)
# Out:
#        status  card_present_flag bpay_biller_code         account currency  \
# 0  authorized                1.0              NaN  ACC-1598451071      AUD
# 1  authorized                0.0              NaN  ACC-1598451071      AUD
# 2  authorized                1.0              NaN  ACC-1222300524      AUD
#
#         long_lat txn_description                           merchant_id  \
# 0  153.41 -27.95             POS  81c48296-73be-44a7-befa-d053f48ce7cd
# 1  153.41 -27.95       SALES-POS  830a451c-316e-4a6a-bf25-e37caedca49e
# 2  151.23 -33.94             POS  835c231d-8cdf-4e96-859d-e9d571760cf0
#
#   first_name  balance       date gender  age merchant_suburb merchant_state  \
# 0      Diana    35.39 2018-08-01      F   26         Ashmore            QLD
# 1      Diana    21.20 2018-08-01      F   26          Sydney            NSW
# 2    Michael     5.71 2018-08-01      M   38          Sydney            NSW
#
# ...

# %%
type(df1['extraction_time'][0])
# Out:
# datetime.time

# %%
df1['extraction_hour'] = pd.to_datetime(df1['extraction'], format='%Y-%m-%d %H:%M:%S').dt.hour
df1.head(3)
# Out:
#        status  card_present_flag bpay_biller_code         account currency  \
# 0  authorized                1.0              NaN  ACC-1598451071      AUD
# 1  authorized                0.0              NaN  ACC-1598451071      AUD
# 2  authorized                1.0              NaN  ACC-1222300524      AUD
#
#         long_lat txn_description                           merchant_id  \
# 0  153.41 -27.95             POS  81c48296-73be-44a7-befa-d053f48ce7cd
# 1  153.41 -27.95       SALES-POS  830a451c-316e-4a6a-bf25-e37caedca49e
# 2  151.23 -33.94             POS  835c231d-8cdf-4e96-859d-e9d571760cf0
#
#   first_name  balance       date gender  age merchant_suburb merchant_state  \
# 0      Diana    35.39 2018-08-01      F   26         Ashmore            QLD
# 1      Diana    21.20 2018-08-01      F   26          Sydney            NSW
# 2    Michael     5.71 2018-08-01      M   38          Sydney            NSW
#
# ...

# %%
df1.tail(3)
# Out:
#            status  card_present_flag bpay_biller_code         account  \
# 12040  authorized                1.0              NaN  ACC-3827517394
# 12041  authorized                1.0              NaN  ACC-2920611728
# 12042  authorized                1.0              NaN  ACC-1443681913
#
#       currency       long_lat txn_description  \
# 12040      AUD  151.12 -33.89             POS
# 12041      AUD  144.96 -37.76       SALES-POS
# 12042      AUD  150.92 -33.77       SALES-POS
#
#                                 merchant_id first_name   balance       date  \
# 12040  e5975ab4-08f7-4725-a369-24cc0e35ed6e      Craig  45394.57 2018-10-31
# 12041  af49051a-591d-4b08-bd3c-27730b70ed37      Tyler  11350.67 2018-10-31
# 12042  f31f4b14-2040-40ec-a120-b141bb274cbd       Ryan   5517.91 2018-10-31
#
#       gender  age merchant_suburb merchant_state  \
# 12040      M   28      Kings Park            NSW
# 12041      M   69        Oakleigh            VIC
# ...

# %%
plt.bar(df1['extraction_hour'], df1['amount'])
plt.xlabel('Hour of Transaction (h)')
plt.ylabel('Amount of Transaction (AUD)')
plt.title('Transaction Amount per Hour for ANZ')
# Out:
# Text(0.5, 1.0, 'Transaction Amount per Hour for ANZ')

# %% [markdown]
# The highest volume of transactions (more than 8000AUD) were done at 1PM.

# %%
vals = df1['movement'].value_counts()
vals
# Out:
# debit     11160
# credit      883
# Name: movement, dtype: int64

# %%
vals.index
# Out:
# Index(['debit', 'credit'], dtype='object')

# %%
plt.bar(vals.index, vals)
plt.xlabel('Type of Transaction')
plt.ylabel('Total Number of Transactions')
plt.title('Credit and Debit Transactions in ANZ Data')
# Out:
# Text(0.5, 1.0, 'Credit and Debit Transactions in ANZ Data')

# %%
df1['movement'].value_counts(normalize=True)*100
# Out:
# debit     92.66794
# credit     7.33206
# Name: movement, dtype: float64

# %% [markdown]
# 93% of the transactions were debit purchases.

# %% [markdown]
# Export the data as a csv file for further analysis in other applications.

# %%
df1.to_csv('df1')
